# %% [markdown]
# # Python Basic Operators:

# %% [markdown]
# # 1. Arthematic Operators:  +, -, *, /, //, %, **

# %%
x , y  = 4 ,  2

# %%
x+y
# Out:
# 6

# %%
x-y
# Out:
# 2

# %%
x*y        # 4 * 2 = 8
# Out:
# 8

# %%
x**y      # 4 power 2 = 16
# Out:
# 16

# %%
x / y         #float Division
# Out:
# 2.0

# %%
x // y        # Interger Division
# Out:
# 2

# %%
x % y         # % = modulas--->(for Remainder)
# Out:
# 0

# %% [markdown]
# # 2. Assignment Operators:  +=, -=, *=, /= , //=, %=, ==

# %%
x = 4

# %%
x == 2
# Out:
# False

# %%
x += 2
x
# Out:
# 6

# %%
x -= 2
x
# Out:
# 4

# %%
x *= 2
x
# Out:
# 8

# %%
x /= 2
x
# Out:
# 4.0

# %%
x //= 2
x
# Out:
# 2.0

# %%
x %= 2
x
# Out:
# 0.0

# %%
#    x * = 2      
# OUTPUT: SyntaxError: invalid syntax 
# no space should be given between operators

# %% [markdown]
# # 3. Unary Operators: Negation (-1)

# %%
# Unary Means 1 | Binary means 2 
# Here we are applying Unary minus Operator (-).

# %%
n = 7 # negation
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
-n
# Out:
# -7

# %% [markdown]
# # 4. Relational Operators: < ,>,  <= , >= , == , !=,

# %%
# We are using this Operators to Compare

# %%
a = 5
b = 7

# %%
a < b
# Out:
# True

# %%
b < a
# Out:
# False

# %%
a = b

# %%
a == b
# Out:
# True

# %%
c = 5
d = 7

# %%
c == d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 5
# 7

# %%
c != d
# Out:
# True

# %%
d != c
# Out:
# True

# %%
c > d
# Out:
# False

# %%
c >= d
# Out:
# False

# %%
c
# Out:
# 5

# %% [markdown]
# # 5. Logical Operators: and , or , not Gates (Truth Table)

# %% [markdown]
# ![And, Or, Not Table.jpg](attachment:bf716094-f765-4e75-bfd2-04e986501f66.jpg)

# %%
# <img src="Table.jpg" style="width:500px;height:350px"/>

# %%
a = 6 
b = 8
a and b
# Out:
# 8

# %%
a < 7 and b < 9
# Out:
# True

# %%
a <  8 and b < 5
# Out:
# False

# %%
a < 8 or b < 5
# Out:
# True

# %%
(45 % 5 == 0) and (45 % 6 == 0)
# Out:
# False

# %%
(45 % 5 == 0) or (45 % 6 == 0)
# Out:
# True

# %% [markdown]
# # print():

# %% [markdown]
# # 1. print result with string:

# %%
# in print(), Make sure do not make Variable as String

# %%
num1 = 20
num2 = 40
add = num1 + num2
print(add)
# Out:
# 60

# %%
num1 = 20
num2 = 40
add = num1 + num2
print('The Addition of', add)
# Out:
# The Addition of 60
